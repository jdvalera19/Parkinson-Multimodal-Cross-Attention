# %%
import os
import matplotlib.pyplot as plt

from Utils.visualization import *

# %% [markdown]
# #### Vowels

# %%
audio_path = 'Results/Note:AUDIO:LOO_data_v2_balanced-Lr:1e-05-Epoch:30-Exercise:Vowels-duration_size:False.csv'
video_path = 'Results/Note:VIDEO:LOO_data_v2_balanced-Lr:0.001-Epoch:10-Exercise:Vowels-duration_size:False.csv'
save_name  = 'results_words'
alpha      = 0.8
print('Audio')
view_results(audio_path)
print('Video')
view_results(video_path)

generate_final_visualization(audio_path,
                             video_path,
                             save_name,
                             'Patient IDS',
                             alpha)

data_vowels = audio_visual_evaluation(audio_path,
                                      video_path)
# Out:
# Audio
# ==========================================================================================
# Precision:0.5624, Recall:0.5531, F1-score:0.5577, Accuracy:0.5614, AUC:0.5680
# ==========================================================================================
# Video
# ==========================================================================================
# Precision:0.4970, Recall:0.2985, F1-score:0.3730, Accuracy:0.4982, AUC:0.5194
# ==========================================================================================
# ---------------------------------------
# AUC:0.59
# ---------------------------------------
# V:0.1 ; A:0.9 ; AUC:0.58
# V:0.15 ; A:0.85 ; AUC:0.58
# V:0.2 ; A:0.8 ; AUC:0.59
# V:0.25 ; A:0.75 ; AUC:0.59
# V:0.3 ; A:0.7 ; AUC:0.59
# V:0.35 ; A:0.65 ; AUC:0.59
# V:0.4 ; A:0.6 ; AUC:0.59
# V:0.45 ; A:0.55 ; AUC:0.58
# V:0.5 ; A:0.5 ; AUC:0.58
# V:0.55 ; A:0.45 ; AUC:0.59
# V:0.6 ; A:0.4 ; AUC:0.58
# V:0.65 ; A:0.35 ; AUC:0.58
# V:0.7 ; A:0.3 ; AUC:0.57
# V:0.75 ; A:0.25 ; AUC:0.57
# V:0.8 ; A:0.2 ; AUC:0.56
# V:0.85 ; A:0.15 ; AUC:0.56
# V:0.9 ; A:0.1 ; AUC:0.55

# %% [markdown]
# #### Phonemes

# %%
audio_path = 'Results/Note:AUDIO:LOO_data_v2_balanced-Lr:1e-05-Epoch:30-Exercise:Phonemes-duration_size:False.csv'
video_path = 'Results/Note:VIDEO:LOO_data_v2_balanced-Lr:0.001-Epoch:10-Exercise:Phonemes-duration_size:False.csv'
save_name  = 'results_Phonemes'
alpha      = 0.65

print('Audio')
view_results(audio_path)
print('Video')
view_results(video_path)

generate_final_visualization(audio_path,
                             video_path,
                             save_name,
                             'Patient IDS',
                             alpha)

data_vowels = audio_visual_evaluation(audio_path,
                                      video_path)
# Out:
# Audio
# ==========================================================================================
# Precision:0.6259, Recall:0.6190, F1-score:0.6225, Accuracy:0.6245, AUC:0.6531
# ==========================================================================================
# Video
# ==========================================================================================
# Precision:0.6716, Recall:0.4121, F1-score:0.5108, Accuracy:0.6053, AUC:0.5423
# ==========================================================================================
# ---------------------------------------
# AUC:0.66
# ---------------------------------------
# V:0.1 ; A:0.9 ; AUC:0.66
# V:0.15 ; A:0.85 ; AUC:0.66
# V:0.2 ; A:0.8 ; AUC:0.66
# V:0.25 ; A:0.75 ; AUC:0.66
# V:0.3 ; A:0.7 ; AUC:0.66
# V:0.35 ; A:0.65 ; AUC:0.66
# V:0.4 ; A:0.6 ; AUC:0.65
# V:0.45 ; A:0.55 ; AUC:0.65
# V:0.5 ; A:0.5 ; AUC:0.64
# V:0.55 ; A:0.45 ; AUC:0.64
# V:0.6 ; A:0.4 ; AUC:0.63
# V:0.65 ; A:0.35 ; AUC:0.62
# V:0.7 ; A:0.3 ; AUC:0.6
# V:0.75 ; A:0.25 ; AUC:0.59
# V:0.8 ; A:0.2 ; AUC:0.58
# V:0.85 ; A:0.15 ; AUC:0.57
# V:0.9 ; A:0.1 ; AUC:0.57

# %% [markdown]
# #### Words

# %%
audio_path = 'Results/Note:AUDIO:LOO_data_v2_balanced-Lr:1e-05-Epoch:30-Exercise:Words-duration_size:False.csv'
video_path = 'Results/Note:VIDEO:LOO_data_v2_balanced-Lr:0.001-Epoch:20-Exercise:Words-duration_size:False.csv'
save_name  = 'results_words'
alpha      = 0.8

print('Audio')
view_results(audio_path)
print('Video')
view_results(video_path)

generate_final_visualization(audio_path,
                             video_path,
                             save_name,
                             'Patient IDS',
                             alpha)

data_vowels = audio_visual_evaluation(audio_path,
                                      video_path)
# Out:
# Audio
# ==========================================================================================
# Precision:0.5000, Recall:0.4267, F1-score:0.4605, Accuracy:0.5000, AUC:0.4885
# ==========================================================================================
# Video
# ==========================================================================================
# Precision:0.4880, Recall:0.2234, F1-score:0.3065, Accuracy:0.4945, AUC:0.4551
# ==========================================================================================
# ---------------------------------------
# AUC:0.49
# ---------------------------------------
# V:0.1 ; A:0.9 ; AUC:0.49
# V:0.15 ; A:0.85 ; AUC:0.49
# V:0.2 ; A:0.8 ; AUC:0.49
# V:0.25 ; A:0.75 ; AUC:0.48
# V:0.3 ; A:0.7 ; AUC:0.48
# V:0.35 ; A:0.65 ; AUC:0.48
# V:0.4 ; A:0.6 ; AUC:0.48
# V:0.45 ; A:0.55 ; AUC:0.48
# V:0.5 ; A:0.5 ; AUC:0.47
# V:0.55 ; A:0.45 ; AUC:0.47
# V:0.6 ; A:0.4 ; AUC:0.47
# V:0.65 ; A:0.35 ; AUC:0.47
# V:0.7 ; A:0.3 ; AUC:0.46
# V:0.75 ; A:0.25 ; AUC:0.46
# V:0.8 ; A:0.2 ; AUC:0.46
# V:0.85 ; A:0.15 ; AUC:0.46
# V:0.9 ; A:0.1 ; AUC:0.46
