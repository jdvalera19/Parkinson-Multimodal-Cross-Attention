# %%
import os
import matplotlib.pyplot as plt

from Utils.visualization import *

# %% [markdown]
# # Vowels

# %% [markdown]
# ### Audio

# %%
view_results('Results/Note:AUDIO:LOO_data_v2_balanced_vgg16_without_weights-Lr:1e-05-Epoch:100-Exercise:Vowels-duration_size:False.csv')
# Out:
# ...
# Precision:0.5925, Recall:0.5751, F1-score:0.5836, Accuracy:0.5897, AUC:0.6257
# ...

# %%
view_results('Results/Note:AUDIO:LOO_data_v2_balanced_vgg16_weights-Lr:1e-05-Epoch:100-Exercise:Vowels-duration_size:False.csv')
# Out:
# ...
# Precision:0.5670, Recall:0.5348, F1-score:0.5504, Accuracy:0.5632, AUC:0.6005
# ...

# %%
view_results('Results/Note:AUDIO:LOO_data_v2_balanced_without_weights-Lr:1e-05-Epoch:100-Exercise:Vowels-duration_size:False.csv')
# Out:
# ...
# Precision:0.5972, Recall:0.6245, F1-score:0.6106, Accuracy:0.6016, AUC:0.6126
# ...

# %%
view_results('Results/Note:AUDIO:LOO_data_v2_balanced-Lr:1e-05-Epoch:30-Exercise:Vowels-duration_size:False.csv')
# Out:
# ...
# Precision:0.5624, Recall:0.5531, F1-score:0.5577, Accuracy:0.5614, AUC:0.5680
# ...

# %% [markdown]
# ## Video

# %%
view_results('Results/Note:VIDEO:LOO_data_v2_balanced-Lr:1e-05-Epoch:50-Exercise:Vowels-duration_size:False.csv')
# Out:
# ...
# Precision:0.6787, Recall:0.5842, F1-score:0.6280, Accuracy:0.6538, AUC:0.6421
# ...

# %%
view_results('Results/Note:VIDEO:LOO_data_v2_balanced_without_weights-Lr:0.0001-Epoch:25-Exercise:Vowels-duration_size:False.csv')
# Out:
# ...
# Precision:0.4365, Recall:0.4341, F1-score:0.4353, Accuracy:0.4368, AUC:0.4559
# ...

# %% [markdown]
# ## 2D baseline

# %%
view_results('Results/Note:2D baseline-Lr:1e-06-Epoch:10-Exercise:vowels.csv')
# Out:
# ...
# Precision:0.4879, Recall:0.4432, F1-score:0.4645, Accuracy:0.5518, AUC:0.6172
# ...

# %% [markdown]
# ## Integration

# %%
audio_path = 'Results/Note:AUDIO:LOO_data_v2_balanced_vgg16_without_weights-Lr:1e-05-Epoch:100-Exercise:Vowels-duration_size:False.csv'
video_path = 'Results/Note:VIDEO:LOO_data_v2_balanced-Lr:1e-05-Epoch:50-Exercise:Vowels-duration_size:False.csv'
save_name  = 'results_vowels'
alpha      = 0.25
print('Audio')
view_results(audio_path)
print('Video')
view_results(video_path)

generate_final_visualization(audio_path,
                             video_path,
                             save_name,
                             'Patient IDS',
                             alpha)

data_vowels = audio_visual_evaluation(audio_path,
                                      video_path)
# Out:
# Audio
# ...
# Precision:0.5925, Recall:0.5751, F1-score:0.5836, Accuracy:0.5897, AUC:0.6257
# ...
# Video
# ...
# Precision:0.6787, Recall:0.5842, F1-score:0.6280, Accuracy:0.6538, AUC:0.6421
# ...
# ---------------------------------------
# AUC:0.7
# ---------------------------------------
# V:0.1 ; A:0.9 ; AUC:0.67
# V:0.15 ; A:0.85 ; AUC:0.67
# V:0.2 ; A:0.8 ; AUC:0.67
# V:0.25 ; A:0.75 ; AUC:0.67
# V:0.3 ; A:0.7 ; AUC:0.67
# V:0.35 ; A:0.65 ; AUC:0.67
# V:0.4 ; A:0.6 ; AUC:0.67
# V:0.45 ; A:0.55 ; AUC:0.68
# V:0.5 ; A:0.5 ; AUC:0.68
# V:0.55 ; A:0.45 ; AUC:0.69
# V:0.6 ; A:0.4 ; AUC:0.69
# V:0.65 ; A:0.35 ; AUC:0.7
# V:0.7 ; A:0.3 ; AUC:0.7
# V:0.75 ; A:0.25 ; AUC:0.7
# V:0.8 ; A:0.2 ; AUC:0.69
# V:0.85 ; A:0.15 ; AUC:0.69
# V:0.9 ; A:0.1 ; AUC:0.68

# %% [markdown]
# # Phonemes

# %% [markdown]
# ## Audio

# %%
view_results('Results/Note:AUDIO:LOO_data_v2_balanced_vgg16_without_weights-Lr:1e-05-Epoch:100-Exercise:Phonemes-duration_size:False.csv')
# Out:
# ...
# Precision:0.6016, Recall:0.5641, F1-score:0.5822, Accuracy:0.5952, AUC:0.6202
# ...

# %%
view_results('Results/Note:AUDIO:LOO_data_v2_balanced_vgg16_weights-Lr:1e-05-Epoch:100-Exercise:Phonemes-duration_size:False.csv')
# Out:
# ...
# Precision:0.6245, Recall:0.5788, F1-score:0.6008, Accuracy:0.6154, AUC:0.6758
# ...

# %%
view_results('Results/Note:AUDIO:LOO_data_v2_balanced_without_weights-Lr:1e-05-Epoch:100-Exercise:Phonemes-duration_size:False.csv')
# Out:
# ...
# Precision:0.5608, Recall:0.5824, F1-score:0.5714, Accuracy:0.5632, AUC:0.5745
# ...

# %%
view_results('Results/Note:AUDIO:LOO_data_v2_balanced-Lr:1e-05-Epoch:30-Exercise:Phonemes-duration_size:False.csv')
# Out:
# ...
# Precision:0.6259, Recall:0.6190, F1-score:0.6225, Accuracy:0.6245, AUC:0.6531
# ...

# %% [markdown]
# ## Video

# %%
view_results('Results/Note:VIDEO:LOO_data_v2_balanced-Lr:0.001-Epoch:10-Exercise:Phonemes-duration_size:False.csv')
# Out:
# ...
# Precision:0.5506, Recall:0.3590, F1-score:0.4346, Accuracy:0.5330, AUC:0.5421
# ...

# %%
view_results('Results/Note:VIDEO:LOO_data_v2_balanced_without_weights-Lr:0.0001-Epoch:25-Exercise:Phonemes-duration_size:False.csv')
# Out:
# ...
# Precision:0.2911, Recall:0.3407, F1-score:0.3139, Accuracy:0.2555, AUC:0.1973
# ...

# %%
view_results('Results/Note:2D baseline-Lr:1e-06-Epoch:10-Exercise:Phonemes.csv')
# Out:
# ...
# Precision:0.6545, Recall:0.4579, F1-score:0.5388, Accuracy:0.6562, AUC:0.6729
# ...

# %% [markdown]
# ## Integration

# %%
audio_path = 'Results/Note:AUDIO:LOO_data_v2_balanced-Lr:1e-05-Epoch:30-Exercise:Phonemes-duration_size:False.csv'
video_path = 'Results/Note:VIDEO:LOO_data_v2_balanced-Lr:0.001-Epoch:10-Exercise:Phonemes-duration_size:False.csv'
save_name  = 'results_Phonemes'
alpha      = 0.65

print('Audio')
view_results(audio_path)
print('Video')
view_results(video_path)

generate_final_visualization(audio_path,
                             video_path,
                             save_name,
                             'Patient IDS',
                             alpha)

data_phonemes = audio_visual_evaluation(audio_path,
                                      video_path)
# Out:
# Audio
# ...
# Precision:0.6259, Recall:0.6190, F1-score:0.6225, Accuracy:0.6245, AUC:0.6531
# ...
# Video
# ...
# Precision:0.5506, Recall:0.3590, F1-score:0.4346, Accuracy:0.5330, AUC:0.5421
# ...
# ---------------------------------------
# AUC:0.67
# ---------------------------------------
# V:0.1 ; A:0.9 ; AUC:0.67
# V:0.15 ; A:0.85 ; AUC:0.67
# V:0.2 ; A:0.8 ; AUC:0.67
# V:0.25 ; A:0.75 ; AUC:0.67
# V:0.3 ; A:0.7 ; AUC:0.67
# V:0.35 ; A:0.65 ; AUC:0.67
# V:0.4 ; A:0.6 ; AUC:0.67
# V:0.45 ; A:0.55 ; AUC:0.67
# V:0.5 ; A:0.5 ; AUC:0.66
# V:0.55 ; A:0.45 ; AUC:0.64
# V:0.6 ; A:0.4 ; AUC:0.63
# V:0.65 ; A:0.35 ; AUC:0.62
# V:0.7 ; A:0.3 ; AUC:0.61
# V:0.75 ; A:0.25 ; AUC:0.6
# V:0.8 ; A:0.2 ; AUC:0.59
# V:0.85 ; A:0.15 ; AUC:0.59
# V:0.9 ; A:0.1 ; AUC:0.58

# %% [markdown]
# # Words

# %% [markdown]
# ## Audio

# %%
view_results('Results/Note:AUDIO:LOO_data_v2_balanced_vgg16_without_weights-Lr:1e-05-Epoch:100-Exercise:Words-duration_size:False.csv')
# Out:
# ...
# Precision:0.5874, Recall:0.5476, F1-score:0.5668, Accuracy:0.5815, AUC:0.6106
# ...

# %%
view_results('Results/Note:AUDIO:LOO_data_v2_balanced_vgg16_weights-Lr:1e-05-Epoch:100-Exercise:Words-duration_size:False.csv')
# Out:
# ...
# Precision:0.5925, Recall:0.5806, F1-score:0.5865, Accuracy:0.5907, AUC:0.6252
# ...

# %%
view_results('Results/Note:AUDIO:LOO_data_v2_balanced_without_weights-Lr:1e-05-Epoch:100-Exercise:Words-duration_size:False.csv')
# Out:
# ...
# Precision:0.5517, Recall:0.6154, F1-score:0.5818, Accuracy:0.5577, AUC:0.5841
# ...

# %%
view_results('Results/Note:AUDIO:LOO_data_v2_balanced-Lr:1e-05-Epoch:30-Exercise:Words-duration_size:False.csv')
# Out:
# ...
# Precision:0.5000, Recall:0.4267, F1-score:0.4605, Accuracy:0.5000, AUC:0.4885
# ...

# %% [markdown]
# ## Video

# %%
view_results('Results/Note:VIDEO:LOO_data_v2_balanced-Lr:0.0001-Epoch:10-Exercise:Words-duration_size:False.csv')
# Out:
# ...
# Precision:0.6424, Recall:0.5165, F1-score:0.5726, Accuracy:0.6145, AUC:0.5638
# ...

# %%
view_results('Results/Note:VIDEO:LOO_data_v2_balanced_without_weights-Lr:0.0001-Epoch:25-Exercise:Words-duration_size:False.csv')
# Out:
# ...
# Precision:0.8337, Recall:0.7619, F1-score:0.7962, Accuracy:0.8049, AUC:0.8425
# ...

# %%
view_results('Results/Note:2D baseline-Lr:1e-06-Epoch:10-Exercise:words.csv')
# Out:
# ...
# Precision:0.6283, Recall:0.5201, F1-score:0.5691, Accuracy:0.6062, AUC:0.6223
# ...

# %%
audio_path = 'Results/Note:AUDIO:LOO_data_v2_balanced_vgg16_weights-Lr:1e-05-Epoch:100-Exercise:Words-duration_size:False.csv'
video_path = 'Results/Note:VIDEO:LOO_data_v2_balanced_without_weights-Lr:0.0001-Epoch:25-Exercise:Words-duration_size:False.csv'
save_name  = 'results_words'
alpha      = 0.1

print('Audio')
view_results(audio_path)
print('Video')
view_results(video_path)

generate_final_visualization(audio_path,
                             video_path,
                             save_name,
                             'Patient IDS',
                             alpha)

data_words = audio_visual_evaluation(audio_path,
                                      video_path)
# Out:
# Audio
# ...
# Precision:0.5925, Recall:0.5806, F1-score:0.5865, Accuracy:0.5907, AUC:0.6252
# ...
# Video
# ...
# Precision:0.8337, Recall:0.7619, F1-score:0.7962, Accuracy:0.8049, AUC:0.8425
# ...
# ---------------------------------------
# AUC:0.86
# ---------------------------------------
# V:0.1 ; A:0.9 ; AUC:0.75
# V:0.15 ; A:0.85 ; AUC:0.75
# V:0.2 ; A:0.8 ; AUC:0.75
# V:0.25 ; A:0.75 ; AUC:0.76
# V:0.3 ; A:0.7 ; AUC:0.76
# V:0.35 ; A:0.65 ; AUC:0.76
# V:0.4 ; A:0.6 ; AUC:0.77
# V:0.45 ; A:0.55 ; AUC:0.77
# V:0.5 ; A:0.5 ; AUC:0.78
# V:0.55 ; A:0.45 ; AUC:0.84
# V:0.6 ; A:0.4 ; AUC:0.85
# V:0.65 ; A:0.35 ; AUC:0.86
# V:0.7 ; A:0.3 ; AUC:0.86
# V:0.75 ; A:0.25 ; AUC:0.86
# V:0.8 ; A:0.2 ; AUC:0.86
# V:0.85 ; A:0.15 ; AUC:0.86
# V:0.9 ; A:0.1 ; AUC:0.86

# %%
import seaborn as sns

# %%
fig, axs = plt.subplots(1, 3, figsize=(20,5), sharey=False)
fig.suptitle('Convex combination evaluation', fontsize=22)

axs[0].plot(data_phonemes["Alphas"], data_phonemes["AUC"], 'o-', label="Phonemes", color = 'limegreen')
axs[0].grid(0.5)
axs[0].set_ylim(0.4, 0.8)
axs[0].axhline(y=0.54, color="red", linestyle="--",alpha=0.8)
axs[0].text(0.1, 0.52, '-Video AUC', fontsize=14, color='black',alpha=0.8)
axs[0].axhline(y=0.65, color="red", linestyle="--",alpha=0.8)
axs[0].text(0.1, 0.63, '-Audio AUC', fontsize=14, color='black',alpha=0.8)
axs[0].text(0.19, 0.71, 'Fusion gain', fontsize=14, color='Red', alpha=0.8)
axs[0].legend()
axs[0].set_ylabel('AUC metric', fontsize=15)
axs[0].annotate("", xy=(0.5, 0.7), xytext=(0.1, 0.7), arrowprops=dict(arrowstyle="<->"), alpha=0.8)

axs[1].plot(data_words["Alphas"]   , data_words["AUC"], 'o-', label="Words", color = "mediumpurple")
axs[1].grid(0.5)
axs[1].set_ylim(0.5, 1)
axs[1].axhline(y=0.62, color="red", linestyle="--", alpha=0.8)
axs[1].text(0.1, 0.59, '-Audio AUC', fontsize=14, color='black', alpha=0.8)
axs[1].axhline(y=0.84, color="red", linestyle="--", alpha=0.8)
axs[1].text(0.1, 0.81, '-Video AUC', fontsize=14, color='black', alpha=0.8)
axs[1].text(0.62, 0.91, 'Fusion gain', fontsize=14, color='Red', alpha=0.8)
axs[1].legend()
axs[1].annotate("", xy=(0.9, 0.9), xytext=(0.55, 0.9), arrowprops=dict(arrowstyle="<->"), alpha=0.8)
axs[1].set_xlabel('$\\beta$ values', fontsize=17)

axs[2].plot(data_vowels["Alphas"]  , data_vowels["AUC"], 'o-', label="Vowels", color="Gray")
axs[2].grid(0.5)
axs[2].set_ylim(0.5, 0.8)
axs[2].axhline(y=0.62, color="red", linestyle="--")
axs[2].text(0.1, 0.60, '-Audio AUC', fontsize=14, color='black', alpha=0.8)
axs[2].axhline(y=0.65, color="red", linestyle="--", alpha=0.8)
axs[2].text(0.1, 0.63, '-Video AUC', fontsize=14, color='black', alpha=0.8)
axs[2].text(0.62, 0.73, 'Fusion gain', fontsize=14, color='Red', alpha=0.8)
axs[2].annotate("", xy=(0.9, 0.72), xytext=(0.55, 0.72), arrowprops=dict(arrowstyle="<->"), alpha=0.8)
axs[2].legend()

plt.savefig('Images/alpha_plot.pdf', bbox_inches='tight')
